# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
from pandas import Series
from numpy.random import randn
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Solar Data

# %%
data1 = pd.read_csv("solar2017.csv")
data2 = pd.read_csv("solar2018.csv")
data3 = pd.read_csv("solar2019.csv")

# %%
data1.head()
# Out:
#    Year  Month  Day  Hour  Minute  Temperature  DHI  DNI  GHI  \
# 0  2017      1    1     0      30         11.7    0    0    0
# 1  2017      1    1     1      30         10.8    0    0    0
# 2  2017      1    1     2      30         10.1    0    0    0
# 3  2017      1    1     3      30          9.6    0    0    0
# 4  2017      1    1     4      30          9.4    0    0    0
#
#    Solar Zenith Angle  Surface Albedo  Wind Speed
# 0              168.64            0.16         1.3
# 1              155.37            0.16         1.2
# 2              141.96            0.16         1.2
# 3              128.64            0.16         1.1
# 4              115.51            0.16         1.1

# %%
data2.head()
# Out:
#    Year  Month  Day  Hour  Minute  Temperature  DHI  DNI  GHI  \
# 0  2018      1    1     0      30         10.1    0    0    0
# 1  2018      1    1     1      30          8.7    0    0    0
# 2  2018      1    1     2      30          7.4    0    0    0
# 3  2018      1    1     3      30          6.5    0    0    0
# 4  2018      1    1     4      30          6.2    0    0    0
#
#    Solar Zenith Angle  Surface Albedo  Wind Speed
# 0              168.62            0.16         1.1
# 1              155.35            0.16         1.3
# 2              141.94            0.16         1.3
# 3              128.62            0.16         1.3
# 4              115.49            0.16         1.3

# %%
data3.head()
# Out:
#    Year  Month  Day  Hour  Minute  Temperature  DHI  DNI  GHI  \
# 0  2019      1    1     0      30          6.3    0    0    0
# 1  2019      1    1     1      30          5.9    0    0    0
# 2  2019      1    1     2      30          5.7    0    0    0
# 3  2019      1    1     3      30          5.8    0    0    0
# 4  2019      1    1     4      30          5.9    0    0    0
#
#    Solar Zenith Angle  Surface Albedo  Wind Speed
# 0              168.60            0.16         1.0
# 1              155.32            0.16         1.1
# 2              141.92            0.16         1.3
# 3              128.60            0.16         1.5
# 4              115.47            0.16         1.7

# %% [markdown]
# # Adding separate Date Time column

# %%
data1["Date_Time"] = pd.to_datetime(data1[["Year", "Month", "Day", "Hour", "Minute"]], format="%Y-%m-%d %H:%M")
print(data1)
data2["Date_Time"] = pd.to_datetime(data2[["Year", "Month", "Day", "Hour", "Minute"]], format="%Y-%m-%d %H:%M")
print(data2)
data3["Date_Time"] = pd.to_datetime(data3[["Year", "Month", "Day", "Hour", "Minute"]], format="%Y-%m-%d %H:%M")
print(data3)
# Out:
#       Year  Month  Day  Hour  Minute  Temperature  DHI  DNI  GHI  \
# 0     2017      1    1     0      30         11.7    0    0    0
# 1     2017      1    1     1      30         10.8    0    0    0
# 2     2017      1    1     2      30         10.1    0    0    0
# 3     2017      1    1     3      30          9.6    0    0    0
# 4     2017      1    1     4      30          9.4    0    0    0
# ...    ...    ...  ...   ...     ...          ...  ...  ...  ...
# 8755  2017     12   31    19      30         17.8    0    0    0
# 8756  2017     12   31    20      30         16.7    0    0    0
# 8757  2017     12   31    21      30         15.4    0    0    0
# 8758  2017     12   31    22      30         14.0    0    0    0
# 8759  2017     12   31    23      30         12.8    0    0    0
#
#       Solar Zenith Angle  Surface Albedo  Wind Speed           Date_Time
# 0                 168.64            0.16         1.3 2017-01-01 00:30:00
# ...

# %%
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
df3=pd.DataFrame(data3)

# %% [markdown]
# # Merging the data

# %%
new_data=pd.concat([df1,df2,df3])

# %%
new_data
# Out:
#       Year  Month  Day  Hour  Minute  Temperature  DHI  DNI  GHI  \
# 0     2017      1    1     0      30         11.7    0    0    0
# 1     2017      1    1     1      30         10.8    0    0    0
# 2     2017      1    1     2      30         10.1    0    0    0
# 3     2017      1    1     3      30          9.6    0    0    0
# 4     2017      1    1     4      30          9.4    0    0    0
# ...    ...    ...  ...   ...     ...          ...  ...  ...  ...
# 8755  2019     12   31    19      30         10.0    0    0    0
# 8756  2019     12   31    20      30          9.3    0    0    0
# 8757  2019     12   31    21      30          8.4    0    0    0
# 8758  2019     12   31    22      30          7.6    0    0    0
# 8759  2019     12   31    23      30          6.8    0    0    0
#
#       Solar Zenith Angle  Surface Albedo  Wind Speed           Date_Time
# 0                 168.64            0.16         1.3 2017-01-01 00:30:00
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26280 entries, 0 to 8759
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                26280 non-null  int64
#  1   Month               26280 non-null  int64
#  2   Day                 26280 non-null  int64
#  3   Hour                26280 non-null  int64
#  4   Minute              26280 non-null  int64
#  5   Temperature         26280 non-null  float64
#  6   DHI                 26280 non-null  int64
#  7   DNI                 26280 non-null  int64
#  8   GHI                 26280 non-null  int64
#  9   Solar Zenith Angle  26280 non-null  float64
#  10  Surface Albedo      26280 non-null  float64
#  11  Wind Speed          26280 non-null  float64
#  12  Date_Time           26280 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(8)
# memory usage: 2.8 MB

# %%
new_data.describe()
# Out:
#                Year         Month           Day          Hour   Minute  \
# count  26280.000000  26280.000000  26280.000000  26280.000000  26280.0
# mean    2018.000000      6.526027     15.720548     11.500000     30.0
# std        0.816512      3.447917      8.796414      6.922318      0.0
# min     2017.000000      1.000000      1.000000      0.000000     30.0
# 25%     2017.000000      4.000000      8.000000      5.750000     30.0
# 50%     2018.000000      7.000000     16.000000     11.500000     30.0
# 75%     2019.000000     10.000000     23.000000     17.250000     30.0
# max     2019.000000     12.000000     31.000000     23.000000     30.0
#
#         Temperature           DHI           DNI           GHI  \
# count  26280.000000  26280.000000  26280.000000  26280.000000
# mean      26.464482     98.522032    163.453158    207.044787
# std        8.780490    131.887193    245.073518    290.833659
# min        0.300000      0.000000      0.000000      0.000000
# ...

# %% [markdown]
# # Checking Null values

# %%
new_data.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Hour                  0
# Minute                0
# Temperature           0
# DHI                   0
# DNI                   0
# GHI                   0
# Solar Zenith Angle    0
# Surface Albedo        0
# Wind Speed            0
# Date_Time             0
# dtype: int64

# %%
new_data
# Out:
#       Year  Month  Day  Hour  Minute  Temperature  DHI  DNI  GHI  \
# 0     2017      1    1     0      30         11.7    0    0    0
# 1     2017      1    1     1      30         10.8    0    0    0
# 2     2017      1    1     2      30         10.1    0    0    0
# 3     2017      1    1     3      30          9.6    0    0    0
# 4     2017      1    1     4      30          9.4    0    0    0
# ...    ...    ...  ...   ...     ...          ...  ...  ...  ...
# 8755  2019     12   31    19      30         10.0    0    0    0
# 8756  2019     12   31    20      30          9.3    0    0    0
# 8757  2019     12   31    21      30          8.4    0    0    0
# 8758  2019     12   31    22      30          7.6    0    0    0
# 8759  2019     12   31    23      30          6.8    0    0    0
#
#       Solar Zenith Angle  Surface Albedo  Wind Speed           Date_Time
# 0                 168.64            0.16         1.3 2017-01-01 00:30:00
# ...

# %%
new_data.sample(5).style.background_gradient(cmap='cool')
# Out:
# <style type="text/css">
# #T_070b2_row0_col0, #T_070b2_row0_col5, #T_070b2_row0_col7, #T_070b2_row0_col8, #T_070b2_row0_col11, #T_070b2_row1_col2, #T_070b2_row2_col3, #T_070b2_row2_col9, #T_070b2_row2_col10, #T_070b2_row3_col1, #T_070b2_row4_col6, #T_070b2_row4_col10 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_070b2_row0_col1, #T_070b2_row0_col4, #T_070b2_row1_col0, #T_070b2_row1_col3, #T_070b2_row1_col4, #T_070b2_row1_col10, #T_070b2_row2_col0, #T_070b2_row2_col4, #T_070b2_row2_col5, #T_070b2_row2_col6, #T_070b2_row2_col7, #T_070b2_row2_col8, #T_070b2_row3_col0, #T_070b2_row3_col4, #T_070b2_row3_col10, #T_070b2_row3_col11, #T_070b2_row4_col0, #T_070b2_row4_col2, #T_070b2_row4_col4, #T_070b2_row4_col9 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_070b2_row0_col2 {
#   background-color: #926dff;
#   color: #f1f1f1;
# }
# #T_070b2_row0_col3, #T_070b2_row0_col10 {
#   background-color: #807fff;
#   color: #f1f1f1;
# }
# #T_070b2_row0_col6 {
# ...

# %%
new_data.describe().style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_8d5ee_row0_col0, #T_8d5ee_row0_col1, #T_8d5ee_row0_col2, #T_8d5ee_row0_col3, #T_8d5ee_row0_col4, #T_8d5ee_row0_col5, #T_8d5ee_row0_col6, #T_8d5ee_row0_col7, #T_8d5ee_row0_col8, #T_8d5ee_row0_col9, #T_8d5ee_row0_col10, #T_8d5ee_row0_col11 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_8d5ee_row1_col0, #T_8d5ee_row3_col0, #T_8d5ee_row4_col0, #T_8d5ee_row5_col0, #T_8d5ee_row6_col0, #T_8d5ee_row7_col0 {
#   background-color: #5a3bfd;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# # Data Correlation

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = new_data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
cor_target = abs(cor["GHI"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Temperature           0.523666
# DHI                   0.885010
# DNI                   0.905219
# GHI                   1.000000
# Solar Zenith Angle    0.818477
# Name: GHI, dtype: float64

# %% [markdown]
# # Dropping least correlated data

# %%
df=new_data.drop(['Surface Albedo','Wind Speed'],axis=1)
df
# Out:
#       Year  Month  Day  Hour  Minute  Temperature  DHI  DNI  GHI  \
# 0     2017      1    1     0      30         11.7    0    0    0
# 1     2017      1    1     1      30         10.8    0    0    0
# 2     2017      1    1     2      30         10.1    0    0    0
# 3     2017      1    1     3      30          9.6    0    0    0
# 4     2017      1    1     4      30          9.4    0    0    0
# ...    ...    ...  ...   ...     ...          ...  ...  ...  ...
# 8755  2019     12   31    19      30         10.0    0    0    0
# 8756  2019     12   31    20      30          9.3    0    0    0
# 8757  2019     12   31    21      30          8.4    0    0    0
# 8758  2019     12   31    22      30          7.6    0    0    0
# 8759  2019     12   31    23      30          6.8    0    0    0
#
#       Solar Zenith Angle           Date_Time
# 0                 168.64 2017-01-01 00:30:00
# 1                 155.37 2017-01-01 01:30:00
# 2                 141.96 2017-01-01 02:30:00
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
sns.displot(data=new_data, x="Temperature", kde=True, bins = 100,color = "red", facecolor = "#3F7F7F",height = 5, aspect = 3.5);

# %%
new_data['Month'].nunique()
# Out:
# 12

# %%
n=new_data[new_data.Year==2019]
n
# Out:
#       Year  Month  Day  Hour  Minute  Temperature  DHI  DNI  GHI  \
# 0     2019      1    1     0      30          6.3    0    0    0
# 1     2019      1    1     1      30          5.9    0    0    0
# 2     2019      1    1     2      30          5.7    0    0    0
# 3     2019      1    1     3      30          5.8    0    0    0
# 4     2019      1    1     4      30          5.9    0    0    0
# ...    ...    ...  ...   ...     ...          ...  ...  ...  ...
# 8755  2019     12   31    19      30         10.0    0    0    0
# 8756  2019     12   31    20      30          9.3    0    0    0
# 8757  2019     12   31    21      30          8.4    0    0    0
# 8758  2019     12   31    22      30          7.6    0    0    0
# 8759  2019     12   31    23      30          6.8    0    0    0
#
#       Solar Zenith Angle  Surface Albedo  Wind Speed           Date_Time
# 0                 168.60            0.16         1.0 2019-01-01 00:30:00
# ...

# %%
data_ghi = new_data.pivot_table(values='GHI', index='Hour', columns='Month')

def Daywise_plot(data= None, row = None, col = None, title='GHI'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='red')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        
Daywise_plot(data=data_ghi, row=12, col=3)

# %%
daily_ghi = new_data.groupby('Hour')['GHI'].agg('sum')

ax = daily_ghi.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='blue')
plt.title('Daily GHI')
plt.show()

# %%
solar_irradiation = new_data.pivot_table(values='Temperature', index='Hour', columns='Month')

def Monthwise_plot(data= None, row = None, col = None, title='IRRADIATION'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='blue')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        
Monthwise_plot(data=solar_irradiation, row=12, col=3)

# %%
daily_irradiation= new_data.groupby('Hour')['Temperature'].agg('sum')

ax = daily_ghi.sort_values(ascending=False).plot.bar(figsize=(17,5), legend=True,color='blue')
plt.title('Daily Irradiation')
plt.show()

# %%
sns.lmplot(y="GHI",x="Temperature",hue="Day",col="Month",height=3,col_wrap=4,data=new_data,fit_reg=True)

# %%
new_data['GHI'].value_counts(),new_data.shape
# Out:
# (0       13262
#  8          83
#  7          77
#  11         75
#  5          61
#          ...
#  1013        1
#  1002        1
#  973         1
#  994         1
#  1014        1
#  Name: GHI, Length: 1010, dtype: int64,
#  (26280, 13))

# %%
X=new_data[['Temperature','DNI','DHI','Solar Zenith Angle',]]
y=new_data[['GHI']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred_lr = lr.predict(X_test)
R2_Score_lr = round(r2_score(y_pred_lr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_lr,"%")
# Out:
# R2 Score :  96.54 %

# %%
import math
MSE = np.square(np.subtract(y_test,y_pred_lr)).mean() 
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 53.382294581063235

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
y_pred_rfr = lr.predict(X_test)
R2_Score_rfr = round(r2_score(y_pred_rfr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_rfr,"%")
# Out:
# R2 Score :  96.54 %

# %%
import math
MSE = np.square(np.subtract(y_test,y_pred_rfr)).mean() 
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 53.382294581063235

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train,y_train)

y_pred_dtr = lr.predict(X_test)
R2_Score_dtr = round(r2_score(y_pred_dtr,y_test) * 100, 2)

print("R2 Score : ",R2_Score_dtr,"%")
# Out:
# R2 Score :  96.54 %

# %%
prediction = rfr.predict(X_test)
print(prediction)
# Out:
# [  0.     0.   646.3  ... 723.22   0.     0.  ]

# %%
y_test.shape
# Out:
# (5256, 1)

# %%
y_test= y_test.values.reshape(1,5256)

# %%
cross_checking = pd.DataFrame({'Actual' : y_test.flatten() , 'Predicted' : prediction.flatten()})
cross_checking.head()
# Out:
#    Actual  Predicted
# 0       0       0.00
# 1       0       0.00
# 2     648     646.30
# 3     166     167.17
# 4     432     434.68

# %%
cross_checking['Error'] = cross_checking['Actual'] - cross_checking['Predicted']
cross_checking.head()
# Out:
#    Actual  Predicted  Error
# 0       0       0.00   0.00
# 1       0       0.00   0.00
# 2     648     646.30   1.70
# 3     166     167.17  -1.17
# 4     432     434.68  -2.68

# %%
cross_checking_final  = cross_checking[cross_checking['Error'] <= 20]
cross_checking_final.sample(50).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'font-family': 'Lucida Calligraphy',
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# ...

# %%
import math
MSE = np.square(np.subtract(y_test,prediction)).mean() 
 
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 4.290302296757734
